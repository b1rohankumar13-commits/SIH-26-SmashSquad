# %% [markdown]
# # Bust-label experiments
# Compare absolute, relative, percentile, spatial, and persistence thresholds. Record every version; do not tune on the test period.

# %%
# Load aligned pilot cases and compare candidate label definitions.
