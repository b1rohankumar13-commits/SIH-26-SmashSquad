# %% [markdown]
# # Inspect matching IMD observations
# Check coverage, timestamps, accumulation windows, units, grid orientation, quality flags, and missing values.

# %%
from pathlib import Path
sorted((Path('data/raw/observations/imd')).glob('**/*'))[:10]
