# %% [markdown]
# # Component and fusion model comparison
# Compare XGBoost, ConvLSTM, simple averaging, and logistic fusion by lead day, region, category context, discrimination, and calibration.

# %%
# Load time-separated evaluation predictions here.
