# %% [markdown]
# # Inspect one forecast file
# Verify variables, ensemble members, issue time, lead time, valid time, grid, units, and missing values before scaling acquisition.

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
PROJECT_ROOT
