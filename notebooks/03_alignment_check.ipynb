# %% [markdown]
# # Forecast–observation alignment check
# Confirm that each forecast valid time is paired with the identical observation period after unit conversion and regridding.

# %%
# Display a small table with init_time, lead_hours, valid_time, and observation_time.
